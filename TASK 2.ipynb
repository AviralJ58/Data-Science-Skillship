# %%
import numpy as np
import pandas as pd
import os

# %% [markdown]
# # Flowers

# %% [markdown]
# ### Preprocessing

# %%
iris=pd.read_csv('iris.csv')

# %%
iris
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# Loaded the dataset.

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  150 non-null    float64
#  1   sepal.width   150 non-null    float64
#  2   petal.length  150 non-null    float64
#  3   petal.width   150 non-null    float64
#  4   variety       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# We can see there are no null values.

# %%
iris[iris.duplicated()==True]
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 142           5.8          2.7           5.1          1.9  Virginica

# %%
iris=iris.drop_duplicates()

# %% [markdown]
# The dataset had a duplicate row which had to be removed.

# %% [markdown]
# ### Tasks

# %% [markdown]
# **Task 1**

# %%
iris.variety.value_counts()
# Out:
# Versicolor    50
# Setosa        50
# Virginica     49
# Name: variety, dtype: int64

# %% [markdown]
# We can see the count of each type of flower. The data is evenly distributed.

# %% [markdown]
# **Task 2**

# %%
iris_virginica=iris[iris.variety=='Virginica']

# %%
iris_virginica[iris_virginica['petal.length']>1.5]
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 100           6.3          3.3           6.0          2.5  Virginica
# 101           5.8          2.7           5.1          1.9  Virginica
# 102           7.1          3.0           5.9          2.1  Virginica
# 103           6.3          2.9           5.6          1.8  Virginica
# 104           6.5          3.0           5.8          2.2  Virginica
# 105           7.6          3.0           6.6          2.1  Virginica
# 106           4.9          2.5           4.5          1.7  Virginica
# 107           7.3          2.9           6.3          1.8  Virginica
# 108           6.7          2.5           5.8          1.8  Virginica
# 109           7.2          3.6           6.1          2.5  Virginica
# 110           6.5          3.2           5.1          2.0  Virginica
# 111           6.4          2.7           5.3          1.9  Virginica
# 112           6.8          3.0           5.5          2.1  Virginica
# ...

# %% [markdown]
# We can see all the features of Iris Virginica flower with petal size>1.5.

# %% [markdown]
# **Task 3**

# %%
print("Minimum\n",iris[iris.variety=='Setosa'].min(),'\n')
print("Maximum\n",iris[iris.variety=='Setosa'].max(),'\n')
print("Average\n",iris[iris.variety=='Setosa'].mean(),'\n')
# Out:
# Minimum
#  sepal.length       4.3
# sepal.width        2.3
# petal.length         1
# petal.width        0.1
# variety         Setosa
# dtype: object
#
# Maximum
#  sepal.length       5.8
# sepal.width        4.4
# petal.length       1.9
# petal.width        0.6
# variety         Setosa
# dtype: object
#
# Average
#  sepal.length    5.006
# sepal.width     3.428
# petal.length    1.462
# petal.width     0.246
# dtype: float64

# %%
print("Minimum\n",iris[iris.variety=='Versicolor'].min(),'\n')
print("Maximum\n",iris[iris.variety=='Versicolor'].max(),'\n')
print("Average\n",iris[iris.variety=='Versicolor'].mean(),'\n')
# Out:
# Minimum
#  sepal.length           4.9
# sepal.width              2
# petal.length             3
# petal.width              1
# variety         Versicolor
# dtype: object
#
# Maximum
#  sepal.length             7
# sepal.width            3.4
# petal.length           5.1
# petal.width            1.8
# variety         Versicolor
# dtype: object
#
# Average
#  sepal.length    5.936
# sepal.width     2.770
# petal.length    4.260
# petal.width     1.326
# dtype: float64

# %%
print("Minimum\n",iris[iris.variety=='Virginica'].min(),'\n')
print("Maximum\n",iris[iris.variety=='Virginica'].max(),'\n')
print("Average\n",iris[iris.variety=='Virginica'].mean(),'\n')
# Out:
# Minimum
#  sepal.length          4.9
# sepal.width           2.2
# petal.length          4.5
# petal.width           1.4
# variety         Virginica
# dtype: object
#
# Maximum
#  sepal.length          7.9
# sepal.width           3.8
# petal.length          6.9
# petal.width           2.5
# variety         Virginica
# dtype: object
#
# Average
#  sepal.length    6.604082
# sepal.width     2.979592
# petal.length    5.561224
# petal.width     2.028571
# dtype: float64

# %% [markdown]
# Hence, we obtained maximum, minimum and average of all the features for all different types of flowers.

# %% [markdown]
# # Terrorism

# %% [markdown]
# ### Preprocessing

# %%
terror=pd.read_csv('terrorismData.csv')
terror
# Out:
#         Year  Month  Day             Country            State  \
# 0       1970      7    2  Dominican Republic              NaN
# 1       1970      0    0              Mexico          Federal
# 2       1970      1    0         Philippines           Tarlac
# 3       1970      1    0              Greece           Attica
# 4       1970      1    0               Japan          Fukouka
# ...      ...    ...  ...                 ...              ...
# 181686  2017     12   31             Somalia  Middle Shebelle
# 181687  2017     12   31               Syria         Lattakia
# 181688  2017     12   31         Philippines      Maguindanao
# 181689  2017     12   31               India          Manipur
# 181690  2017     12   31         Philippines      Maguindanao
#
#                              Region           City   Latitude   Longitude  \
# 0       Central America & Caribbean  Santo Domingo  18.456792  -69.951164
# ...

# %% [markdown]
# Loaded the dataset.

# %%
terror.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 17 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Year         181691 non-null  int64
#  1   Month        181691 non-null  int64
#  2   Day          181691 non-null  int64
#  3   Country      181691 non-null  object
#  4   State        181270 non-null  object
#  5   Region       181691 non-null  object
#  6   City         181257 non-null  object
#  7   Latitude     177135 non-null  float64
#  8   Longitude    177134 non-null  float64
#  9   AttackType   181691 non-null  object
#  10  Killed       171378 non-null  float64
#  11  Wounded      165380 non-null  float64
#  12  Target       181055 non-null  object
#  13  Summary      115562 non-null  object
#  14  Group        181691 non-null  object
#  15  Target_type  181691 non-null  object
#  16  Weapon_type  181691 non-null  object
# dtypes: float64(4), int64(3), object(10)
# ...

# %% [markdown]
# We see there are many columns with null values.

# %%
terror=terror.fillna({"Target":'Unknown','Summary':'Unknown','Region':'Unknown','City':'Unknown'})

# %%
terror=terror.fillna({'Latitude':terror['Latitude'].mean(),'Longitude':terror['Longitude'].mean(),'Killed':terror['Killed'].mean(),'Wounded':terror['Wounded'].mean()})

# %%
terror.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 17 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Year         181691 non-null  int64
#  1   Month        181691 non-null  int64
#  2   Day          181691 non-null  int64
#  3   Country      181691 non-null  object
#  4   State        181270 non-null  object
#  5   Region       181691 non-null  object
#  6   City         181691 non-null  object
#  7   Latitude     181691 non-null  float64
#  8   Longitude    181691 non-null  float64
#  9   AttackType   181691 non-null  object
#  10  Killed       181691 non-null  float64
#  11  Wounded      181691 non-null  float64
#  12  Target       181691 non-null  object
#  13  Summary      181691 non-null  object
#  14  Group        181691 non-null  object
#  15  Target_type  181691 non-null  object
#  16  Weapon_type  181691 non-null  object
# dtypes: float64(4), int64(3), object(10)
# ...

# %% [markdown]
# Filled the NA values.

# %%
terror[terror.duplicated()==True]
# Out:
#         Year  Month  Day        Country         State  \
# 68      1970      2   16  United States    California
# 88      1970      2   23  United States      Nebraska
# 89      1970      2   23  United States      Nebraska
# 90      1970      2   23  United States      Nebraska
# 337     1970      6    9         Jordan         Amman
# ...      ...    ...  ...            ...           ...
# 181397  2017     12   18       Pakistan   Balochistan
# 181431  2017     12   20    Philippines   Maguindanao
# 181587  2017     12   27          India  Chhattisgarh
# 181634  2017     12   29         Israel      Southern
# 181657  2017     12   30          Kenya       Garissa
#
#                             Region              City   Latitude   Longitude  \
# 68                   North America          Berkeley  37.874043 -122.280022
# 88                   North America  South Sioux City  42.470310  -96.413949
# 89                   North America  South Sioux City  42.470310  -96.413949
# ...

# %% [markdown]
# Many columns are duplicated.

# %%
terror=terror.drop_duplicates()

# %%
terror=terror.reset_index()

# %%
terror=terror.drop(columns=['index'])

# %% [markdown]
# Dropped the duplicates and resetted the indexing.

# %%
for i in range(len(terror.Month)):
    if terror.Month[i]==0:
        terror.Month[i]=1
for i in range(len(terror.Day)):
    if terror.Day[i]==0:
        terror.Day[i]=1
# Out:
# C:\Users\Aviral.HP-PAVILION\anaconda3\envs\Deep learning\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Aviral.HP-PAVILION\anaconda3\envs\Deep learning\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# Many entries in 'Month' and 'Day' were observed to be 0 which isn't correct and hence we change it to 1.

# %%
terror["Date"]=pd.to_datetime(terror.iloc[:,:3],infer_datetime_format=True)

# %%
terror=terror.drop(columns=['Year','Month','Day'])

# %% [markdown]
# Made a column with Dates of the attack of 'datetime' type.

# %%
terror
# Out:
#                    Country            State                       Region  \
# 0       Dominican Republic              NaN  Central America & Caribbean
# 1                   Mexico          Federal                North America
# 2              Philippines           Tarlac               Southeast Asia
# 3                   Greece           Attica               Western Europe
# 4                    Japan          Fukouka                    East Asia
# ...                    ...              ...                          ...
# 172182             Somalia  Middle Shebelle           Sub-Saharan Africa
# 172183               Syria         Lattakia   Middle East & North Africa
# 172184         Philippines      Maguindanao               Southeast Asia
# 172185               India          Manipur                   South Asia
# 172186         Philippines      Maguindanao               Southeast Asia
#
#                  City   Latitude   Longitude                      AttackType  \
# ...

# %% [markdown]
# ### Tasks

# %% [markdown]
# **Task 1**

# %%
terror.Country.value_counts().head()
# Out:
# Iraq           23458
# Pakistan       13795
# Afghanistan    12512
# India          11585
# Colombia        7504
# Name: Country, dtype: int64

# %% [markdown]
# We see that Iraq had the most terror attacks.

# %%
terror_iraq=terror[terror.Country=='Iraq']

# %%
pd.DatetimeIndex(terror_iraq['Date']).year.value_counts().head()
# Out:
# 2014    3651
# 2016    2850
# 2013    2771
# 2015    2671
# 2017    2292
# Name: Date, dtype: int64

# %% [markdown]
# We can infer that most attacks in Iraq were held in 2014.

# %% [markdown]
# **Task 2**

# %%
terror_india=terror[terror.Country=="India"]
govt=terror_india[terror_india.Date>='2014-05-26']

# %%
govt
# Out:
#        Country              State      Region           City   Latitude  \
# 124685   India     Andhra Pradesh  South Asia    Bandlapalli  14.714739
# 124713   India        West Bengal  South Asia   Sandeshkhali  22.356709
# 124719   India        West Bengal  South Asia   Sandeshkhali  22.363882
# 124742   India  Jammu and Kashmir  South Asia          Khour  32.601778
# 124770   India             Odisha  South Asia      Bikrampur  22.338542
# ...        ...                ...         ...            ...        ...
# 172159   India             Kerala  South Asia  Koothuparamba  11.831902
# 172161   India       Chhattisgarh  South Asia       Toylanka  18.802725
# 172168   India  Jammu and Kashmir  South Asia      Lethapora  33.966527
# 172180   India              Assam  South Asia        Hungrum  25.180162
# 172185   India            Manipur  South Asia         Imphal  24.798346
#
#         Longitude                      AttackType  Killed  Wounded  \
# ...

# %%
govt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3307 entries, 124685 to 172185
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Country      3307 non-null   object
#  1   State        3307 non-null   object
#  2   Region       3307 non-null   object
#  3   City         3307 non-null   object
#  4   Latitude     3307 non-null   float64
#  5   Longitude    3307 non-null   float64
#  6   AttackType   3307 non-null   object
#  7   Killed       3307 non-null   float64
#  8   Wounded      3307 non-null   float64
#  9   Target       3307 non-null   object
#  10  Summary      3307 non-null   object
#  11  Group        3307 non-null   object
#  12  Target_type  3307 non-null   object
#  13  Weapon_type  3307 non-null   object
#  14  Date         3307 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(4), object(10)
# memory usage: 413.4+ KB

# %% [markdown]
# There are 3307 entries in this dataframe which is the number of attacks done in this period.

# %%
govt.Group.value_counts().head()
# Out:
# Unknown                                           1271
# Maoists                                            843
# Communist Party of India - Maoist (CPI-Maoist)     323
# Hizbul Mujahideen (HM)                              78
# Lashkar-e-Taiba (LeT)                               69
# Name: Group, dtype: int64

# %% [markdown]
# Ignoring the Unknown attacks, Maoists were the most active group during this period with 843 attacks.
